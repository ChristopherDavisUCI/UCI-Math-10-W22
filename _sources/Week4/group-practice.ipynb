# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv("../data/spotify.csv", na_values=" ")

# %%
df.columns
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord'],
#       dtype='object')

# %%
pd.to_numeric(df.Streams.map(lambda s: s.replace(",","")))
# Out:
# 0       48633449
# 1       47248719
# 2       40162559
# 3       37799456
# 4       33948454
#           ...
# 1551     4630675
# 1552     4623030
# 1553     4620876
# 1554     4607385
# 1555     4595450
# Name: Streams, Length: 1556, dtype: int64

# %%
for c in df.columns:
    try:
        df[c] = pd.to_numeric(df[c])
    except ValueError:
        pass

# %%
df["Week of Highest Charting"].map(len).value_counts()
# Out:
# 22    1556
# Name: Week of Highest Charting, dtype: int64

# %%
alt.Chart(df).mark_circle().encode(
    x = "Energy",
    y = "Loudness",
    color = "Acousticness"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/math11/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#    2018             copy.data = core.InlineData(values=[{}])
#    2019             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020         return super().to_dict(*args, **kwargs)
#    2021
#    2022     def add_selection(self, *selections):
#
# ~/miniconda3/envs/math11/lib/python3.9/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     382
#     383         try:
# --> 384             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     385         except jsonschema.ValidationError:
#     386             dct = None
#
# ~/miniconda3/envs/math11/lib/python3.9/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
# ...

# %%
df.groupby("Artist").size()
# Out:
# Artist
# *NSYNC                                                                   1
# 13 Organisé, SCH, Kofs, Jul, Naps, Soso Maness, Elams, Solda, Houari     1
# 187 Strassenbande, Bonez MC, Frauenarzt                                  1
# 21 Savage, Metro Boomin                                                 12
# 24kGoldn                                                                 4
#                                                                         ..
# iann dior                                                                1
# jxdn                                                                     1
# salem ilese                                                              1
# sangiovanni                                                              1
# twocolors                                                                1
# Length: 716, dtype: int64

# %%
from vega_datasets import data

# %%
df = data.cars()

# %%
dict(df.groupby("Origin")["Weight_in_lbs"].mean())
# Out:
# {'Europe': 2431.4931506849316,
#  'Japan': 2221.227848101266,
#  'USA': 3372.700787401575}

# %%
df[df.Artist.isin(df.Artist.value_counts().iloc[:12].index)]
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 8         9                          3                        8
# 12       13                          5                        3
# 13       14                          1                       19
# 14       15                          2                       10
# 17       18                          5                       14
# ...     ...                        ...                      ...
# 1499   1500                        100                        1
# 1500   1501                        102                        1
# 1501   1502                        113                        1
# 1549   1550                        187                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting  \
# 8      2021-06-18--2021-06-25
# 12     2021-07-09--2021-07-16
# 13     2021-04-02--2021-04-09
# 14     2021-05-21--2021-05-28
# 17     2021-04-23--2021-04-30
# ...
