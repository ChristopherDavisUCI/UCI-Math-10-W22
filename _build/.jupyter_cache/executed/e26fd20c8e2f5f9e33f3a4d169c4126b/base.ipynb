# %%
import seaborn as sns
import numpy as np
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.metrics import log_loss, mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LinearRegression
from torch import nn

# %%
training = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

training['train_test'] = 1
test['train_test'] = 0
test['Survived'] = np.NaN
df = pd.concat([training,test])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 training = pd.read_csv('train.csv')
#       2 test = pd.read_csv('test.csv')
#       4 training['train_test'] = 1
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.csv'

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 df.dropna(inplace=True)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
for k in df["Cabin"].unique():
    df[f"Cabin_{k}"] = (df["Cabin"] == k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 for k in df["Cabin"].unique():
#       2     df[f"Cabin_{k}"] = (df["Cabin"] == k)
#
# NameError: name 'df' is not defined

# %%
df.head() #check if each Cabin has it's own column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
#def order(char):
    #return ord(char) - ord('A') +1

# %%
#df['deck_num'] = df['deck'].map(lambda s : order(s))

# %%
X_colnames = ["Fare"] + [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
y_colname = 'Survived'
X = df.loc[:, X_colnames].copy()
y = df.loc[:, y_colname].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 X_colnames = ["Fare"] + [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
#       2 y_colname = 'Survived'
#       3 X = df.loc[:, X_colnames].copy()
#
# NameError: name 'df' is not defined

# %%
[f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
#
# NameError: name 'df' is not defined

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <module>
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(X)
#       3 X_scaled = scaler.transform(X)
#
# NameError: name 'X' is not defined

# %%
clf = KNeighborsClassifier(n_neighbors=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
len(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
#       2 len(X_train)
#
# NameError: name 'X' is not defined

# %%
len(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 len(y_train)
#
# NameError: name 'y_train' is not defined

# %%
scaler.fit(X_train)
scaler.fit(X_test)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <module>
# ----> 1 scaler.fit(X_train)
#       2 scaler.fit(X_test)
#       3 X_train_scaled = scaler.transform(X_train)
#
# NameError: name 'X_train' is not defined

# %%
len(X_train_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <module>
# ----> 1 len(X_train_scaled)
#
# NameError: name 'X_train_scaled' is not defined

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <module>
# ----> 1 clf.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
clf.predict_proba(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <module>
# ----> 1 clf.predict_proba(X_scaled)
#
# NameError: name 'X_scaled' is not defined

# %%
clf.score(X_test, y_test, sample_weight = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <module>
# ----> 1 clf.score(X_test, y_test, sample_weight = None)
#
# NameError: name 'X_test' is not defined

# %%
clf.score(X_train, y_train, sample_weight = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <module>
# ----> 1 clf.score(X_train, y_train, sample_weight = None)
#
# NameError: name 'X_train' is not defined

# %%
log_loss(df['Survived'], clf.predict_proba(X_scaled), labels = clf.classes_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <module>
# ----> 1 log_loss(df['Survived'], clf.predict_proba(X_scaled), labels = clf.classes_)
#
# NameError: name 'df' is not defined

# %%
def get_scores(k):
    reg = KNeighborsClassifier(n_neighbors=k)
    reg.fit(X_train, y_train)
    test_error = log_loss(y_test, reg.predict_proba(X_test), labels = reg.classes_)
    return (test_error)

# %%
for i in range(1,11):
    print(f"when n_nearest neighbor is {i}, the test error is {get_scores(i)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <module>
#       1 for i in range(1,11):
# ----> 2     print(f"when n_nearest neighbor is {i}, the test error is {get_scores(i)}")
#
# Input In [23], in get_scores(k)
#       1 def get_scores(k):
#       2     reg = KNeighborsClassifier(n_neighbors=k)
# ----> 3     reg.fit(X_train, y_train)
#       4     test_error = log_loss(y_test, reg.predict_proba(X_test), labels = reg.classes_)
#       5     return (test_error)
#
# NameError: name 'X_train' is not defined

# %%
c1 = alt.Chart(df).mark_circle().encode(
    x = "Cabin:O",
    y = "Fare",
    color = "Survived:N",
    tooltip = ["Fare", "Cabin", "Survived"]
).properties(
    title = "Fare paid for each deck",
    height = 550,
    width = 800
)

c1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <module>
# ----> 1 c1 = alt.Chart(df).mark_circle().encode(
#       2     x = "Cabin:O",
#       3     y = "Fare",
#       4     color = "Survived:N",
#       5     tooltip = ["Fare", "Cabin", "Survived"]
#       6 ).properties(
#       7     title = "Fare paid for each deck",
#       8     height = 550,
#       9     width = 800
#      10 )
#      12 c1
#
# NameError: name 'df' is not defined

# %%
df[df["Fare"] > 500] #check which rows has datas with fare > $500
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 df[df["Fare"] > 500]
#
# NameError: name 'df' is not defined

# %%
df1 = df[~(df["Fare"] > 500)] #Removing the anomaly from the dataset and setting it to df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 df1 = df[~(df["Fare"] > 500)]
#
# NameError: name 'df' is not defined

# %%
c2 = alt.Chart(df1).mark_circle().encode(
    x = "Cabin:O",
    y = "Fare",
    color = "Survived:N",
    tooltip = ["Fare", "Cabin", "Survived"]
).properties(
    title = "Fare paid for each deck",
    height = 550,
    width = 800
)

c2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 c2 = alt.Chart(df1).mark_circle().encode(
#       2     x = "Cabin:O",
#       3     y = "Fare",
#       4     color = "Survived:N",
#       5     tooltip = ["Fare", "Cabin", "Survived"]
#       6 ).properties(
#       7     title = "Fare paid for each deck",
#       8     height = 550,
#       9     width = 800
#      10 )
#      12 c2
#
# NameError: name 'df1' is not defined

# %%
X_colnames = ["Fare"] + [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
y_colname = 'Survived'
X1 = df1.loc[:, X_colnames].copy()
y1 = df1.loc[:, y_colname].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <module>
# ----> 1 X_colnames = ["Fare"] + [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
#       2 y_colname = 'Survived'
#       3 X1 = df1.loc[:, X_colnames].copy()
#
# NameError: name 'df' is not defined

# %%
#extra 
Cabin_col = [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <module>
#       1 #extra
# ----> 2 Cabin_col = [f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]
#
# NameError: name 'df' is not defined

# %%
clf1 = KNeighborsClassifier(n_neighbors=10)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1,y1,test_size=0.2)
len(X_train1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <module>
# ----> 1 X_train1, X_test1, y_train1, y_test1 = train_test_split(X1,y1,test_size=0.2)
#       2 len(X_train1)
#
# NameError: name 'X1' is not defined

# %%
scaler = StandardScaler()
scaler.fit(X_train1)
scaler.fit(X_test1)
X_train_scaled1 = scaler.transform(X_train1)
X_test_scaled1 = scaler.transform(X_test1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <module>
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(X_train1)
#       3 scaler.fit(X_test1)
#       4 X_train_scaled1 = scaler.transform(X_train1)
#
# NameError: name 'X_train1' is not defined

# %%
scaler.fit(X1)
X_scaled1 = scaler.transform(X1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <module>
# ----> 1 scaler.fit(X1)
#       2 X_scaled1 = scaler.transform(X1)
#
# NameError: name 'X1' is not defined

# %%
clf1.fit(X_train1, y_train1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <module>
# ----> 1 clf1.fit(X_train1, y_train1)
#
# NameError: name 'X_train1' is not defined

# %%
clf1.predict_proba(X_scaled1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [36], in <module>
# ----> 1 clf1.predict_proba(X_scaled1)
#
# NameError: name 'X_scaled1' is not defined

# %%
clf1.score(X_test1, y_test1, sample_weight = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <module>
# ----> 1 clf1.score(X_test1, y_test1, sample_weight = None)
#
# NameError: name 'X_test1' is not defined

# %%
clf1.score(X_train1, y_train1, sample_weight = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <module>
# ----> 1 clf1.score(X_train1, y_train1, sample_weight = None)
#
# NameError: name 'X_train1' is not defined

# %%
log_loss(df1['Survived'], clf1.predict_proba(X_scaled1), labels = clf.classes_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <module>
# ----> 1 log_loss(df1['Survived'], clf1.predict_proba(X_scaled1), labels = clf.classes_)
#
# NameError: name 'df1' is not defined

# %%
kreg = KNeighborsRegressor(n_neighbors=10)

# %%
kreg.fit(X_train1, y_train1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <module>
# ----> 1 kreg.fit(X_train1, y_train1)
#
# NameError: name 'X_train1' is not defined

# %%
kreg.predict(X_scaled1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <module>
# ----> 1 kreg.predict(X_scaled1)
#
# NameError: name 'X_scaled1' is not defined

# %%
#since KNeighborsRegressor does not have a predict_proba attribute, we use .predict
kreg.score(X_test1, y_test1, sample_weight = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <module>
#       1 #since KNeighborsRegressor does not have a predict_proba attribute, we use .predict
# ----> 2 kreg.score(X_test1, y_test1, sample_weight = None)
#
# NameError: name 'X_test1' is not defined

# %%
kreg.score(X_train1, y_train1, sample_weight = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <module>
# ----> 1 kreg.score(X_train1, y_train1, sample_weight = None)
#
# NameError: name 'X_train1' is not defined

# %%
mean_squared_error(df1['Survived'], kreg.predict(X_scaled1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <module>
# ----> 1 mean_squared_error(df1['Survived'], kreg.predict(X_scaled1))
#
# NameError: name 'df1' is not defined

# %%
lr = LogisticRegression(max_iter = 2000)
cv = cross_val_score(lr,X_train_scaled1,y_train1,cv=5)
print(cv)
print(cv.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <module>
#       1 lr = LogisticRegression(max_iter = 2000)
# ----> 2 cv = cross_val_score(lr,X_train_scaled1,y_train1,cv=5)
#       3 print(cv)
#       4 print(cv.mean())
#
# NameError: name 'X_train_scaled1' is not defined

# %%
knn = KNeighborsClassifier()
cv = cross_val_score(knn,X_train1,y_train1,cv=5)
print(cv)
print(cv.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <module>
#       1 knn = KNeighborsClassifier()
# ----> 2 cv = cross_val_score(knn,X_train1,y_train1,cv=5)
#       3 print(cv)
#       4 print(cv.mean())
#
# NameError: name 'X_train1' is not defined

# %%
rf = RandomForestClassifier(random_state = 1)
cv = cross_val_score(rf,X_train1,y_train1,cv=5)
print(cv)
print(cv.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <module>
#       1 rf = RandomForestClassifier(random_state = 1)
# ----> 2 cv = cross_val_score(rf,X_train1,y_train1,cv=5)
#       3 print(cv)
#       4 print(cv.mean())
#
# NameError: name 'X_train1' is not defined

# %%
voting_clf = VotingClassifier(estimators = [('lr',lr),('knn',knn),('rf',rf)], voting = 'soft')

# %%
cv = cross_val_score(voting_clf,X_train_scaled1,y_train1,cv=5)
print(cv)
print(cv.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <module>
# ----> 1 cv = cross_val_score(voting_clf,X_train_scaled1,y_train1,cv=5)
#       2 print(cv)
#       3 print(cv.mean())
#
# NameError: name 'X_train_scaled1' is not defined

# %%
clfo = LogisticRegression()

# %%
clfo.fit(X_train1, y_train1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <module>
# ----> 1 clfo.fit(X_train1, y_train1)
#
# NameError: name 'X_train1' is not defined

# %%
clfo.predict(X_train1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <module>
# ----> 1 clfo.predict(X_train1)
#
# NameError: name 'X_train1' is not defined

# %%
np.count_nonzero(clfo.predict(X_test1) == y_test1)/len(X_test1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [54], in <module>
# ----> 1 np.count_nonzero(clfo.predict(X_test1) == y_test1)/len(X_test1)
#
# NameError: name 'X_test1' is not defined

# %%
np.count_nonzero(clfo.predict(X_train1) == y_train1)/len(X_train1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <module>
# ----> 1 np.count_nonzero(clfo.predict(X_train1) == y_train1)/len(X_train1)
#
# NameError: name 'X_train1' is not defined

# %%
reg = LinearRegression()

# %%
reg.fit(df[["Fare",]], df["Survived"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [57], in <module>
# ----> 1 reg.fit(df[["Fare",]], df["Survived"])
#
# NameError: name 'df' is not defined

# %%
reg.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [58], in <module>
# ----> 1 reg.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <module>
# ----> 1 reg.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
def draw_line(m,b):
    alt.data_transformers.disable_max_rows()

    d1 = alt.Chart(df1).mark_circle().encode(
        x = "Fare",
        y = "Survived"
    )

    xmax = 40
    df_line = pd.DataFrame({"Fare":[0,xmax],"Survived":[b,xmax*m]})
    d2 = alt.Chart(df_line).mark_line(color="red").encode(
        x = "Fare",
        y = "Survived"
    )
    return d1+d2

# %%
draw_line(0.00082767, 0.6070082823070905)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <module>
# ----> 1 draw_line(0.00082767, 0.6070082823070905)
#
# Input In [60], in draw_line(m, b)
#       1 def draw_line(m,b):
#       2     alt.data_transformers.disable_max_rows()
# ----> 4     d1 = alt.Chart(df1).mark_circle().encode(
#       5         x = "Fare",
#       6         y = "Survived"
#       7     )
#       9     xmax = 40
#      10     df_line = pd.DataFrame({"Fare":[0,xmax],"Survived":[b,xmax*m]})
#
# NameError: name 'df1' is not defined

# %%
reg1 = LinearRegression()

# %%
reg1.fit(df[[f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]], df["Survived"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [63], in <module>
# ----> 1 reg1.fit(df[[f"Cabin_{k}" for k in sorted(df["Cabin"].unique())]], df["Survived"])
#
# NameError: name 'df' is not defined

# %%
reg.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [64], in <module>
# ----> 1 reg.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <module>
# ----> 1 reg.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
def draw_line(m,b):
    alt.data_transformers.disable_max_rows()

    d1 = alt.Chart(df).mark_circle().encode(
        x = "Cabin:O",
        y = "Survived"
    )

    xmax = 40
    df_line = pd.DataFrame({"Cabin":[0,xmax],"Survived":[b,xmax*m]})
    d2 = alt.Chart(df_line).mark_line(color="red").encode(
        x = "Cabin",
        y = "Survived"
    )
    return d1+d2

# %%
draw_line(1.1276363e+14, -112763629749553.84)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <module>
# ----> 1 draw_line(1.1276363e+14, -112763629749553.84)
#
# Input In [66], in draw_line(m, b)
#       1 def draw_line(m,b):
#       2     alt.data_transformers.disable_max_rows()
# ----> 4     d1 = alt.Chart(df).mark_circle().encode(
#       5         x = "Cabin:O",
#       6         y = "Survived"
#       7     )
#       9     xmax = 40
#      10     df_line = pd.DataFrame({"Cabin":[0,xmax],"Survived":[b,xmax*m]})
#
# NameError: name 'df' is not defined
